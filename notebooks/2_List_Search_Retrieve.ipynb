# %% [markdown]
# # Copyright 2026 Cognite AS
#
# ## Import the Libraries and Modules

# %%
import sys
from pathlib import Path

utils = str(Path("../utils").resolve())
if utils not in sys.path:
    sys.path.append(utils)

from cognite_auth import interactive_client

# %% [markdown]
# ## Create the Cognite Client

# %%
client = interactive_client()

# %%
from datetime import datetime, UTC

from cognite.client.data_classes.data_modeling.cdm.v1 import (
    CogniteTimeSeries,
    CogniteActivity,
    CogniteAsset,
)
from cognite.client.data_classes.data_modeling import (
    DirectRelationReference,
    NodeId,
    ViewId,
)
from cognite.client.data_classes import filters

# %% [markdown]
# ### List data

# %% [markdown]
# Running the first command might open a new tab to verify the log in, if so, you can close that tab and come back to the notebook.

# %% [markdown]
# Below, we will look at how you can list different types of data from CDF. Note that when we list instances, we list all types of data from CDF, the `instance_type` tells us if it is a node or an edge. Unless we provide a source to retrieve properties from, the returned data is just the basic properties like space, external ID and timestamps corresponding to when the instance was created and last updated.
#
# **Good to know**: You can use `list` when you want to run basic queries. Later, we'll take a look at the much more powerful `query` endpoint.

# %%
client.data_modeling.instances.list(space="world_data", limit=10)
# Out:
# NodeList([<Node(space='world_data', external_id='region:Africa', version=17) at 0x1d6f23bd400>,
#           <Node(space='world_data', external_id='region:Americas', version=18) at 0x1d6f25e0e10>,
#           <Node(space='world_data', external_id='region:Asia', version=18) at 0x1d6f248ed50>,
#           <Node(space='world_data', external_id='region:Europe', version=18) at 0x1d6f24c7820>,
#           <Node(space='world_data', external_id='region:Oceania', version=16) at 0x1d6f25d8050>,
#           <Node(space='world_data', external_id='CAN', version=18) at 0x1d6e9f25b50>,
#           <Node(space='world_data', external_id='CCK', version=15) at 0x1d6f21ee9c0>,
#           <Node(space='world_data', external_id='PRK', version=18) at 0x1d6f25318c0>,
#           <Node(space='world_data', external_id='COL', version=18) at 0x1d6f254e950>,
#           <Node(space='world_data', external_id='ZMB', version=17) at 0x1d6f254f050>])

# %% [markdown]
# If we want to filter for specific `instance_type`:
# (here looking at edges, we can see the `start_node` and `end_note`)

# %%
client.data_modeling.instances.list(space="world_data", instance_type='edge', limit=5)
# Out:
# EdgeList([<Edge(space='world_data', external_id='LH67HoHcjgG0mynKwMAnW90Jzur6IEFR87nAVf3AhNM=', version=1) at 0x1d6f25278c0>,
#           <Edge(space='world_data', external_id='-EX-brCFeAhjgOgy28QMG1fZkgQnStsKMlLhZZCt3sk=', version=1) at 0x1d6f248fb10>,
#           <Edge(space='world_data', external_id='AeKi03ctSCGn7Xv0k-XQvUm1Y5JxFuYJwEOMNZH79vI=', version=1) at 0x1d6f4915f90>,
#           <Edge(space='world_data', external_id='3co_Jd6AFhEZ3qgW0174rx8xpIJ0HlDH4CowsqrES4o=', version=1) at 0x1d6f24c75c0>,
#           <Edge(space='world_data', external_id='N5j2tVhNz6AxgtugdQv4LzLTaa1qDoTJ_FuFVdQxvbQ=', version=1) at 0x1d6f48f6060>])

# %% [markdown]
# #### List CogniteTimeSeries instances from the core data model

# %%
tss = client.data_modeling.instances.list(
    sources=CogniteTimeSeries.get_source(),
    limit=5,  # or None for all
)

# Convert to pandas DataFrame
df = tss.to_pandas()
df
# Out:
#         space external_id  version       last_updated_time  \
# 0  world_data         CAN       18 2026-03-04 15:32:11.692
# 1  world_data         PRK       18 2026-03-04 15:32:11.692
# 2  world_data         COL       18 2026-03-04 15:32:11.692
# 3  world_data         ZMB       17 2026-03-04 15:32:11.692
# 4  world_data         TGO       17 2026-03-04 15:32:11.692
#
#              created_time instance_type                       name  \
# 0 2026-02-06 12:34:33.386          node                     Canada
# 1 2026-02-06 12:34:33.386          node  Korea, Dem. People's Rep.
# 2 2026-02-06 12:34:33.386          node                   Colombia
# 3 2026-02-06 12:34:33.386          node                     Zambia
# 4 2026-02-06 12:34:33.386          node                       Togo
#
#                                         description     type  \
# 0                                   Country: Canada  numeric
# 1  Country: Korea (Democratic People's Republic of)  numeric
# 2                                 Country: Colombia  numeric
# 3                                   Country: Zambia  numeric
# 4                                     Country: Togo  numeric
#
#                                            assets  isStep equipment
# 0  [{'space': 'world_data', 'externalId': 'CAN'}]   False        []
# 1  [{'space': 'world_data', 'externalId': 'PRK'}]   False        []
# 2  [{'space': 'world_data', 'externalId': 'COL'}]   False        []
# 3  [{'space': 'world_data', 'externalId': 'ZMB'}]   False        []
# 4  [{'space': 'world_data', 'externalId': 'TGO'}]   False        []

# %% [markdown]
# #### Listing CogniteActivities

# %%
client.data_modeling.instances.list(sources=CogniteActivity.get_source(), limit=5)
# Out:
# NodeList([<Node(space='world_data', external_id='2021-0134-GRC', version=1) at 0x21ca022bbf0>,
#           <Node(space='world_data', external_id='2017-0015-ITA', version=1) at 0x21c9ddb5d00>,
#           <Node(space='world_data', external_id='2017-0350-CHE', version=1) at 0x21ce05747c0>,
#           <Node(space='world_data', external_id='2017-0280-GRC', version=1) at 0x21ce0578a50>,
#           <Node(space='world_data', external_id='2014-0174-GRC', version=1) at 0x21ce0578e50>])

# %% [markdown]
# ## Searching in CDF
#
# - Search the CDF resource types
# - Filter the search results

# %% [markdown]
# ### Exact search on one field (e.g. name, description etc)

# %%
# In this exercise, we will search using the Cognite Asset view:
asset_view_id = CogniteAsset.get_source()

# %%
res = client.data_modeling.instances.search(
    view=asset_view_id,
    query="islands",
    properties=["name"],
)
res.to_pandas()["name"]
# Out:
# 0                          Cocos (Keeling) Islands
# 1                                    Åland Islands
# 2                                     Cook Islands
# 3                                    Faroe Islands
# 4                         Northern Mariana Islands
# 5                Heard Island and McDonald Islands
# 6                                 Marshall Islands
# 7                                  Solomon Islands
# 8                      Falkland Islands (Malvinas)
# 9                            Virgin Islands (U.S.)
# 10    South Georgia and the South Sandwich Islands
# 11                                  Cayman Islands
# 12            United States Minor Outlying Islands
# 13                        Turks and Caicos Islands
# 14                          British Virgin Islands
# Name: name, dtype: str

# %% [markdown]
# ### Search using multiple terms with at least one matching
#
# By default, the search operator AND is used when multiple search terms are provided. Thus, we pass OR in the query below:

# %%
res = client.data_modeling.instances.search(
    view=asset_view_id,
    query="Canada Norway Australia",
    properties=["name"],
    operator="OR",
)
res
# Out:
# NodeList([<Node(space='world_data', external_id='CAN', version=18) at 0x24fbf741e50>,
#           <Node(space='world_data', external_id='NOR', version=18) at 0x24fbf741fd0>,
#           <Node(space='world_data', external_id='AUS', version=16) at 0x24fbf73b960>])

# %% [markdown]
# #### Get all time series for the above asset

# %%
time_series_view_id = CogniteTimeSeries.get_source()

res = client.data_modeling.instances.search(
    view=time_series_view_id,
    filter=filters.ContainsAny(
        # We use the time series view to reference the 'assets' property, which is a list of
        # direct relations to connected assets
        property=time_series_view_id.as_property_ref("assets"),
        values=[DirectRelationReference("world_data", "CAN")],
    )
)

res
# Out:
# NodeList([<Node(space='world_data', external_id='CAN', version=18) at 0x24fbf73b800>])

# %% [markdown]
# ## Retrieve data from CDF

# %% [markdown]
# ### Retrieve datapoints from time series

# %%
dps_list = client.time_series.data.retrieve(
    instance_id=[
        NodeId("world_data", "NRU"),
        NodeId("world_data", "ESP"),
    ],
    start=datetime(2000, 1, 1, tzinfo=UTC),
    end=datetime(2024, 1, 2, tzinfo=UTC),
    limit=10,
)

dps_list

# %% [markdown]
# #### Retrieve all items related to an asset

# %%
# We have a node representing Europe:
europe = client.data_modeling.instances.retrieve_nodes(
    NodeId("world_data", "region:Europe"),
    node_cls=CogniteAsset,
)
# Let's check out what the parent of Europe is:
europe.parent
# Out:
# DirectRelationReference(space='world_data', external_id='global')

# %% [markdown]
# #### Let's now fetch the children of this asset (i.e. countries in Europe)

# %%
countries = client.data_modeling.instances.list(
    sources=asset_view_id,
    filter=filters.Equals(
        property=asset_view_id.as_property_ref("parent"),
        value=europe.as_id(),
    ),
    limit=None,
)
len(countries)
# Out:
# 51

# %% [markdown]
# #### Retrieve events ('activities')

# %%
activity_view = CogniteActivity.get_source()

events = client.data_modeling.instances.search(
    view=activity_view,
    filter=filters.ContainsAny(
        property=activity_view.as_property_ref("assets"),
        values=[DirectRelationReference("world_data", "ITA")],
    ),
    limit=5,
)
events

# %% [markdown]
# #### Retrieve datapoints after 2020 for three countries

# %%
italia_id = NodeId("world_data", "ITA")
norway_id = NodeId("world_data", "NOR")
france_id = NodeId("world_data", "FRA")

df = client.time_series.data.retrieve_dataframe(
    instance_id=[italia_id, norway_id, france_id],
    start=datetime(2020, 1, 1, tzinfo=UTC)
)
df
# Out:
# identifier           NodeId(space='world_data', external_id='ITA')  \
# 2020-12-31 23:00:00                                     60627498.0
# 2021-12-31 23:00:00                                     60536709.0
# 2022-12-31 23:00:00                                     60421760.0
# 2023-12-31 23:00:00                                     59729081.0
# 2024-12-31 23:00:00                                     59449527.0
# 2025-12-31 23:00:00                                     59066225.0
#
# identifier           NodeId(space='world_data', external_id='NOR')  \
# 2020-12-31 23:00:00                                      5234519.0
# 2021-12-31 23:00:00                                      5276968.0
# 2022-12-31 23:00:00                                      5311916.0
# 2023-12-31 23:00:00                                      5347896.0
# 2024-12-31 23:00:00                                      5379475.0
# 2025-12-31 23:00:00                                      5408320.0
#
# identifier           NodeId(space='world_data', external_id='FRA')
# 2020-12-31 23:00:00                                     66724104.0
# 2021-12-31 23:00:00                                     66918020.0
# 2022-12-31 23:00:00                                     67101930.0
# 2023-12-31 23:00:00                                     67248926.0
# 2024-12-31 23:00:00                                     67379908.0
# 2025-12-31 23:00:00                                     67499343.0

# %%
# To extract the data for France, you can pass a NodeId:
df[france_id]

# %% [markdown]
# ### Retrieve aggregated data using a granularity of 10 years

# %%
df = client.time_series.data.retrieve_dataframe(
    instance_id=italia_id,
    aggregates=["average", "max", "min"],
    granularity="10y",
)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 df = client.time_series.data.retrieve_dataframe(
# ----> 2     instance_id=italia_id,
#       3     aggregates=["average", "max", "min"],
#       4     granularity="10y",
#       5 )
#
# NameError: name 'italia_id' is not defined

# %%
# To extract the "max" aggregate, you can do the following:
df[italia_id, "max"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # To extract the "max" aggregate, you can do the following:
# ----> 2 df[italia_id, "max"]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Retrieve latest datapoint before a particular time (last or any past time point)

# %%
latest_dp = client.time_series.data.retrieve_latest(
    instance_id=norway_id,
    before="5w-ago",  # when not given, uses 'now'
)
latest_dp
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>value</th>
#       <td>5408320.0</td>
#     </tr>
#     <tr>
#       <th>timestamp</th>
#       <td>2025-12-31 23:00:00+00:00</td>
#     </tr>
#     <tr>
#       <th>before</th>
#       <td>2026-06-14 02:11:33.219000+00:00</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>4295045892524413</td>
#     </tr>
#     <tr>
#       <th>is_string</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>is_step</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>type</th>
#       <td>numeric</td>
#     </tr>
#     <tr>
#       <th>unit</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>unit_external_id</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>instance_id</th>
#       <td>{'space': 'world_data', 'external_id': 'NOR'}</td>
#     </tr>
#     <tr>
#       <th>datapoints</th>
#       <td>[{'timestamp': 1767222000000, 'value': 5408320...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Plot datapoints
# #### **Note**: Requires matplotlib to be installed

# %%
client.time_series.data.retrieve(
    instance_id=[norway_id, italia_id, france_id]
).to_pandas().plot();
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 client.time_series.data.retrieve(
#       2     instance_id=[norway_id, italia_id, france_id]
# ----> 3 ).to_pandas().plot();
#
# File e:\source\repos\streamlit\myenv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File e:\source\repos\streamlit\myenv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
#
# File e:\source\repos\streamlit\myenv\Lib\site-packages\pandas\plotting\_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
